# %%
import requests
from bs4 import BeautifulSoup as bs
from pprint import pprint as p

# %%
url = "https://suvarnabhumi.airportthai.co.th/flight"

# %%
page = requests.get(url)
soup = bs(page.text, 'html.parser')
p(soup.prettify())
# Out:
# ('<!DOCTYPE html>\n'
#  '<html class="h-100">\n'
#  ' <head>\n'
#  '  <script>\n'
#  "   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\n"
#  "                new Date().getTime(),event:'gtm.js'});var "
#  'f=d.getElementsByTagName(s)[0],\n'
#  '                '
#  "j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\n"
#  '                '
#  "'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\n"
#  "                })(window,document,'script','dataLayer','GTM-KQMCNX6');\n"
#  '  </script>\n'
#  '  <script async="" '
#  'src="https://www.googletagmanager.com/gtag/js?id=G-NFQC3J94CH">\n'
#  '  </script>\n'
#  '  <script>\n'
#  '   window.dataLayer = window.dataLayer || [];\n'
#  '                function gtag(){dataLayer.push(arguments);}\n'
#  "                gtag('js', new Date());\n"
#  "                gtag('config', 'G-NFQC3J94CH');\n"
#  '  </script>\n'
#  '  <meta content="Cr4RlRC2Tl18wHMJYJpXvgvgt14ED9P3luW7XFFTpoQ" '
#  'name="google-site-verification"/>\n'
#  '  <meta charset="utf-8"/>\n'
#  '  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" '
#  'name="viewport"/>\n'
#  '  <link href="./images/favicons/aot_apple_180.png" rel="apple-touch-icon" '
#  'sizes="180x180"/>\n'
#  '  <link href="/images/favicons/aot32.png" rel="icon" sizes="32x32" '
#  'type="image/png"/>\n'
#  '  <link href="/images/favicons/aot16.png" rel="icon" sizes="16x16" '
#  'type="image/png"/>\n'
#  '  <link href="/images/favicons/aot.ico" rel="icon"/>\n'
#  '  <title>\n'
#  '   Flight\n'
#  '  </title>\n'
#  '  <meta content="7" name="next-head-count"/>\n'
#  '  <link as="style" href="/_next/static/css/59a672578d32b93a8a88.css" '
#  'rel="preload"/>\n'
#  '  <link data-n-g="" href="/_next/static/css/59a672578d32b93a8a88.css" '
#  'rel="stylesheet"/>\n'
#  '  <link as="style" href="/_next/static/css/79a21f5d02cb876a520b.css" '
#  'rel="preload"/>\n'
#  '  <link data-n-p="" href="/_next/static/css/79a21f5d02cb876a520b.css" '
#  'rel="stylesheet"/>\n'
#  '  <noscript data-n-css="">\n'
#  '  </noscript>\n'
#  '  <link as="script" '
#  'href="/_next/static/chunks/webpack-fe4b4968ddeab099efef.js" rel="preload"/>\n'
#  '  <link as="script" '
#  'href="/_next/static/chunks/framework-106d25c2ed81dc45938c.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" href="/_next/static/chunks/main-1edd7ef5819b2a11bbed.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" '
#  'href="/_next/static/chunks/pages/_app-d75b3491177b58aeb9b6.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" '
#  'href="/_next/static/chunks/29107295-a36037e5ea1af0472eba.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" '
#  'href="/_next/static/chunks/cb1608f2-0acd0fa0d973384ecfed.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" '
#  'href="/_next/static/chunks/75fc9c18-5f9e88d02b7fe80f33f9.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" href="/_next/static/chunks/6067-d5bbd6667205f733b73a.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" href="/_next/static/chunks/4635-893cbd8a482370a1a834.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" href="/_next/static/chunks/2959-4bb853920bbbf98e78e0.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" href="/_next/static/chunks/1796-bd3f82c7fdb482ac6e18.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" href="/_next/static/chunks/2238-f7ba2e2bd779585fd5b7.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" href="/_next/static/chunks/9607-1201740d0f1621f67209.js" '
#  'rel="preload"/>\n'
#  '  <link as="script" '
#  'href="/_next/static/chunks/pages/flight-8506b04b6caec7ae1fa9.js" '
#  'rel="preload"/>\n'
#  ' </head>\n'
#  ' <body class="d-flex flex-column h-100">\n'
#  '  <noscript>\n'
#  '   <iframe height="0" '
#  'src="https://www.googletagmanager.com/ns.html?id=GTM-KQMCNX6" '
#  'style="display:none;visibility:hidden" width="0">\n'
#  '   </iframe>\n'
#  '  </noscript>\n'
#  '  <div id="__next">\n'
#  '   <nav class="navbar navbar-expand-xl nav_airport main_pad">\n'
#  '    <div class="collapse navbar-collapse" id="navbarSupportedContent">\n'
#  '     <ul class="navbar-nav mr-auto">\n'
#  '      <li class="nav-item active">\n'
#  '       <a class="nav-link" href="https://suvarnabhumi.airportthai.co.th/">\n'
#  '        <div class="airport_name">\n'
#  '         ท่าอากาศยานสุวรรณภูมิ\n'
#  '        </div>\n'
#  '        <div class="airport_text">\n'
#  '        </div>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="nav-item">\n'
#  '       <a class="nav-link" href="https://donmueang.airportthai.co.th/">\n'
#  '        <div class="airport_name">\n'
#  '         ท่าอากาศยานดอนเมือง\n'
#  '        </div>\n'
#  '        <div class="airport_text">\n'
#  '        </div>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="nav-item">\n'
#  '       <a class="nav-link" href="https://chiangmai.airportthai.co.th/">\n'
#  '        <div class="airport_name">\n'
#  '         ท่าอากาศยานเชียงใหม่\n'
#  '        </div>\n'
#  '        <div class="airport_text">\n'
#  '        </div>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="nav-item">\n'
#  '       <a class="nav-link" href="https://chiangrai.airportthai.co.th/">\n'
#  '        <div class="airport_name">\n'
#  '         ท่าอากาศยานแม่ฟ้าหลวง เชียงราย\n'
#  '        </div>\n'
#  '        <div class="airport_text">\n'
#  '        </div>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="nav-item">\n'
#  '       <a class="nav-link" href="https://hatyai.airportthai.co.th/">\n'
#  '        <div class="airport_name">\n'
#  '         ท่าอากาศยานหาดใหญ่\n'
#  '        </div>\n'
#  '        <div class="airport_text">\n'
#  '        </div>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="nav-item">\n'
#  '       <a class="nav-link" href="https://phuket.airportthai.co.th/">\n'
#  '        <div class="airport_name">\n'
#  '         ท่าอากาศยานภูเก็ต\n'
#  '        </div>\n'
#  '        <div class="airport_text">\n'
#  '        </div>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '     </ul>\n'
#  '    </div>\n'
#  '    <div>\n'
#  '     <ul class="navbar-nav nav_right">\n'
#  '      <li class="nav-item">\n'
#  '       <a class="nav-link" href="/login">\n'
#  '        <div class="btn_login nav_r">\n'
#  '         <img alt="user-circle-solid" '
#  'src="/images/navbar/user-circle-solid.svg"/>\n'
#  '         <span>\n'
#  '          เข้าสู่ระบบ\n'
#  '         </span>\n'
#  '        </div>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="nav-item">\n'
#  '       <a class="nav-link nav_search">\n'
#  '        <div class="btn_search nav_r">\n'
#  '         <img alt="search-solid-2.svg" '
#  'src="/images/navbar/search-solid-2.svg"/>\n'
#  '        </div>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <div class="dropdown">\n'
#  '       <button aria-expanded="false" aria-haspopup="true" '
#  'class="dropdown-toggle btn btn-primary" id="dropdown-basic-button" '
#  'type="button">\n'
#  '        ไทย\n'
#  '       </button>\n'
#  '      </div>\n'
#  '     </ul>\n'
#  '    </div>\n'
#  '   </nav>\n'
#  '   <nav class="navbar navbar-expand-xl nav_menu main_pad navbar '
#  'navbar-expand-xl navbar-light bg-light">\n'
#  '    <a class="aot_logo navbar-brand" href="/">\n'
#  '     <img alt="aot_logo" class="d-inline-block align-top mb_hide" '
#  'src="/images/navbar/aot_logo.png"/>\n'
#  '     <img alt="aot_logo_white" class="d-inline-block align-top desktop_hide" '
#  'src="/images/navbar/aot_logo_white.png"/>\n'
#  '    </a>\n'
#  '    <div class="navbar-collapse collapse" id="menu-navbar-nav">\n'
#  '     <div class="desktop_hide wrap_select_airport">\n'
#  '      <div class="main_font font-18">\n'
#  '       สนามบิน\n'
#  '      </div>\n'
#  '      <div class="wrap_main_dropdown">\n'
#  '       <select class="main_dropdown mb-2 main_font font-18">\n'
#  '        <option selected="" '
#  'value="https://suvarnabhumi.airportthai.co.th/">\n'
#  '         ท่าอากาศยานสุวรรณภูมิ\n'
#  '        </option>\n'
#  '        <option value="https://donmueang.airportthai.co.th/">\n'
#  '         ท่าอากาศยานดอนเมือง\n'
#  '        </option>\n'
#  '        <option value="https://chiangmai.airportthai.co.th/">\n'
#  '         ท่าอากาศยานเชียงใหม่\n'
#  '        </option>\n'
#  '        <option value="https://chiangrai.airportthai.co.th/">\n'
#  '         ท่าอากาศยานแม่ฟ้าหลวง เชียงราย\n'
#  '        </option>\n'
#  '        <option value="https://hatyai.airportthai.co.th/">\n'
#  '         ท่าอากาศยานหาดใหญ่\n'
#  '        </option>\n'
#  '        <option value="https://phuket.airportthai.co.th/">\n'
#  '         ท่าอากาศยานภูเก็ต\n'
#  '        </option>\n'
#  '       </select>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '     <div class="ml-auto navbar-nav">\n'
#  '      <a class="nav-item nav-link" data-rb-event-key="/flight/" '
#  'href="/flight/" prefetch="false">\n'
#  '       เที่ยวบิน\n'
#  '      </a>\n'
#  '      <a class="nav-item nav-link" data-rb-event-key="/service/" '
#  'href="/service/" prefetch="false">\n'
#  '       คู่มือสนามบิน\n'
#  '      </a>\n'
#  '      <a class="nav-item nav-link" data-rb-event-key="/promotion/" '
#  'href="/promotion/" prefetch="false">\n'
#  '       สิทธิพิเศษ\n'
#  '      </a>\n'
#  '      <a class="nav-item nav-link" data-rb-event-key="/explore/" '
#  'href="/explore/" prefetch="false">\n'
#  '       เที่ยวไทย\n'
#  '      </a>\n'
#  '      <a class="nav-item nav-link" data-rb-event-key="/contact-us/" '
#  'href="/contact-us/" prefetch="false">\n'
#  '       ติดต่อเรา\n'
#  '      </a>\n'
#  '     </div>\n'
#  '     <div class="btn_login_mb desktop_hide">\n'
#  '      <img alt="user-circle-solid" '
#  'src="/images/navbar/user-circle-solid.svg"/>\n'
#  '      <span>\n'
#  '       เข้าสู่ระบบ\n'
#  '      </span>\n'
#  '     </div>\n'
#  '    </div>\n'
#  '    <div>\n'
#  '     <ul class="navbar-nav nav_right">\n'
#  '      <li class="nav-item">\n'
#  '       <a class="nav-link nav_search">\n'
#  '        <div class="btn_search nav_r">\n'
#  '         <img alt="search-solid-2" '
#  'src="/images/navbar/search-solid-2.svg"/>\n'
#  '        </div>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="nav-item dropdown right_line">\n'
#  '       <div class="dropdown">\n'
#  '        <button aria-expanded="false" aria-haspopup="true" '
#  'class="dropdown-toggle btn btn-primary" id="dropdown-basic-button" '
#  'type="button">\n'
#  '         ไทย\n'
#  '        </button>\n'
#  '       </div>\n'
#  '      </li>\n'
#  '      <button aria-controls="navbarMenu" aria-expanded="false" '
#  'aria-label="Toggle navigation" class="navbar-toggler navbar-toggler '
#  'collapsed" id="btn_toggler_menu" type="button">\n'
#  '       <span class="navbar-toggler-icon">\n'
#  '       </span>\n'
#  '      </button>\n'
#  '     </ul>\n'
#  '    </div>\n'
#  '   </nav>\n'
#  '   <div class="wrap_header_banner carousel slide">\n'
#  '    <ol class="carousel-indicators">\n'
#  '     <li class="active">\n'
#  '     </li>\n'
#  '    </ol>\n'
#  '    <div class="carousel-inner">\n'
#  '     <div class="active carousel-item">\n'
#  '      <img alt="IMG_3943.jpg" class="d-block w-100 mb_hide" '
#  'src="https://apis.airportthai.co.th/microsite/images/banners/IMG_3943.jpg"/>\n'
#  '      <img alt="IMG_3947.jpg" class="desktop_hide d-block w-100" '
#  'src="https://apis.airportthai.co.th/microsite/images/banners/IMG_3947.jpg"/>\n'
#  '      <div class="HeaderBanner_wrap_text_header__2IwjX">\n'
#  '       <div class="HeaderBanner_text_header_title__2ASvk">\n'
#  '        เที่ยวบิน\n'
#  '       </div>\n'
#  '       <div class="HeaderBanner_text_header_detail__1EhnH">\n'
#  '        ติดตามผู้โดยสารที่มาถึงเที่ยวบินพร้อมการอัปเดต\n'
#  '       </div>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </div>\n'
#  '    <a class="carousel-control-prev" href="#" role="button">\n'
#  '    </a>\n'
#  '    <a class="carousel-control-next" href="#" role="button">\n'
#  '    </a>\n'
#  '   </div>\n'
#  '   <div class="HeaderBanner_wrap_navigator__2gGA-">\n'
#  '    <div class="container">\n'
#  '     <div class="row">\n'
#  '      <div class="col" cs="12">\n'
#  '       <a href="/">\n'
#  '        หน้าแรก\n'
#  '       </a>\n'
#  '       <span>\n'
#  '        เที่ยวบิน\n'
#  '       </span>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </div>\n'
#  '   </div>\n'
#  '   <div class="undefined wrap_flight_list">\n'
#  '    <div class="block_content_main container">\n'
#  '     <div class="row">\n'
#  '      <div class="col-12">\n'
#  '       <div class="flight_type active" data-value="a">\n'
#  '        เที่ยวบินเข้า\n'
#  '       </div>\n'
#  '       <div class="flight_type" data-value="d">\n'
#  '        เที่ยวบินออก\n'
#  '       </div>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '     <div class="Flight_wrap_flight_input__8Ln5D small_pad_col">\n'
#  '      <div class="row">\n'
#  '       <div class="col-md-6 col-sm-12 col-12">\n'
#  '        <div class="wrap_input_group">\n'
#  '         <input placeholder="ค้นหาเที่ยวบินเข้า" type="text" value=""/>\n'
#  '         <img alt="" src="../../../images/main/i_plane.svg"/>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '       <div class="col-md-3 col-sm-6 col-6">\n'
#  '        <div class="wrap_input_group parent">\n'
#  '         <input/>\n'
#  '         <img alt="" class="absolute" '
#  'src="../../../images/main/i_calendar.svg"/>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '       <div class="col-md-3 col-sm-6 col-6">\n'
#  '        <div class="wrap_input_group">\n'
#  '         <input/>\n'
#  '         <img alt="" class="absolute_time" '
#  'src="../../../images/main/i_clock.svg"/>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '      </div>\n'
#  '      <div class="mt-2 row">\n'
#  '       <div class="col-md-6 col-7">\n'
#  '        <span class="Flight_update_time__2wC2m">\n'
#  '         *\n'
#  '         <!-- -->\n'
#  '         ข้อมูลล่าสุด\n'
#  '         <!-- -->\n'
#  '         :\n'
#  '         <!-- -->\n'
#  '         (\n'
#  '         <!-- -->\n'
#  '         เวลาประเทศไทย GMT+7\n'
#  '         <!-- -->\n'
#  '         )\n'
#  '        </span>\n'
#  '       </div>\n'
#  '       <div class="text-right col-md-6 col-5">\n'
#  '        <span class="Flight_refresh__nUNOg">\n'
#  '         <svg aria-hidden="true" class="svg-inline--fa fa-sync-alt fa-w-16" '
#  'data-icon="sync-alt" data-prefix="fas" focusable="false" role="img" '
#  'viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">\n'
#  '          <path d="M370.72 133.28C339.458 104.008 298.888 87.962 255.848 '
#  '88c-77.458.068-144.328 53.178-162.791 126.85-1.344 5.363-6.122 9.15-11.651 '
#  '9.15H24.103c-7.498 0-13.194-6.807-11.807-14.176C33.933 94.924 134.813 8 256 '
#  '8c66.448 0 126.791 26.136 171.315 68.685L463.03 40.97C478.149 25.851 504 '
#  '36.559 504 57.941V192c0 13.255-10.745 24-24 24H345.941c-21.382 '
#  '0-32.09-25.851-16.971-40.971l41.75-41.749zM32 296h134.059c21.382 0 32.09 '
#  '25.851 16.971 40.971l-41.75 41.75c31.262 29.273 71.835 45.319 114.876 45.28 '
#  '77.418-.07 144.315-53.144 162.787-126.849 1.344-5.363 6.122-9.15 '
#  '11.651-9.15h57.304c7.498 0 13.194 6.807 11.807 14.176C478.067 417.076 '
#  '377.187 504 256 504c-66.448 0-126.791-26.136-171.315-68.685L48.97 '
#  '471.03C33.851 486.149 8 475.441 8 454.059V320c0-13.255 10.745-24 24-24z" '
#  'fill="currentColor">\n'
#  '          </path>\n'
#  '         </svg>\n'
#  '         <!-- -->\n'
#  '         รีเฟรซ\n'
#  '        </span>\n'
#  '       </div>\n'
#  '      </div>\n'
#  '      <div class="row">\n'
#  '       <div class="col-12">\n'
#  '        <div class="Flight_wrap_table_flight__31Dn8">\n'
#  '         <table class="Flight_table_flight__1KC0P table table-hover">\n'
#  '          <thead>\n'
#  '           <tr>\n'
#  '            <th>\n'
#  '             SCHEDULED\n'
#  '            </th>\n'
#  '            <th>\n'
#  '             FLIGHT NUMBER\n'
#  '            </th>\n'
#  '            <th>\n'
#  '             AIRLINE\n'
#  '            </th>\n'
#  '            <th>\n'
#  '             FROM\n'
#  '            </th>\n'
#  '            <th>\n'
#  '             BELT\n'
#  '            </th>\n'
#  '            <th>\n'
#  '             STATUS\n'
#  '            </th>\n'
#  '           </tr>\n'
#  '          </thead>\n'
#  '          <tbody>\n'
#  '          </tbody>\n'
#  '         </table>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '       <div class="col-12">\n'
#  '       </div>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </div>\n'
#  '   </div>\n'
#  '   <div>\n'
#  '    <div class="ads text-center">\n'
#  '     <a href="https://bit.ly/2U8GiIh" target="_blank">\n'
#  '      <img alt="" class="ads_img" '
#  'src="https://apis.airportthai.co.th/microsite/images/advertising/MTI3.jpg"/>\n'
#  '     </a>\n'
#  '    </div>\n'
#  '   </div>\n'
#  '   <footer class="footer mt-auto">\n'
#  '    <div class="container">\n'
#  '     <div class="row">\n'
#  '      <div class="col-md-6 col-12">\n'
#  '       <div class="dk_hide footer_mb pt-2">\n'
#  '        <div class="accordion">\n'
#  '         <div class="wrap_footer_mb_menu_item" data-value="0" id="item_0">\n'
#  '          <button class="btn btn-link" data-item="0" data-value="0" '
#  'type="button">\n'
#  '           <div class="wrap_footer_mb_menu main_font font-18" '
#  'data-value="0">\n'
#  '            เที่ยวบิน\n'
#  '            <div class="footer_mb_arrow" data-value="0">\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </button>\n'
#  '          <div class="collapse">\n'
#  '           <div class="wrap_footer_mb_all_sub_menu">\n'
#  '            <div class="wrap_footer_mb_sub_menu">\n'
#  '             <a href="/flight?type=a">\n'
#  '              <div class="footer_circle">\n'
#  '              </div>\n'
#  '              เที่ยวบินเข้า\n'
#  '             </a>\n'
#  '            </div>\n'
#  '            <div class="wrap_footer_mb_sub_menu">\n'
#  '             <a href="/flight?type=d">\n'
#  '              <div class="footer_circle">\n'
#  '              </div>\n'
#  '              เที่ยวบินออก\n'
#  '             </a>\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </div>\n'
#  '         </div>\n'
#  '         <div class="wrap_footer_mb_menu_item" data-value="1" id="item_1">\n'
#  '          <button class="btn btn-link" data-item="1" data-value="1" '
#  'type="button">\n'
#  '           <div class="wrap_footer_mb_menu main_font font-18" '
#  'data-value="1">\n'
#  '            สิทธิพิเศษ\n'
#  '            <div class="footer_mb_arrow" data-value="1">\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </button>\n'
#  '          <div class="collapse">\n'
#  '           <div class="wrap_footer_mb_all_sub_menu">\n'
#  '            <div class="wrap_footer_mb_sub_menu">\n'
#  '             <a href="/promotion/privilege">\n'
#  '              <div class="footer_circle">\n'
#  '              </div>\n'
#  '              สิทธิพิเศษ\n'
#  '             </a>\n'
#  '            </div>\n'
#  '            <div class="wrap_footer_mb_sub_menu">\n'
#  '             <a href="/promotion/booking">\n'
#  '              <div class="footer_circle">\n'
#  '              </div>\n'
#  '              จองสิทธิพิเศษ\n'
#  '             </a>\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </div>\n'
#  '         </div>\n'
#  '         <div class="wrap_footer_mb_menu_item" data-value="2" id="item_2">\n'
#  '          <button class="btn btn-link" data-item="2" data-value="2" '
#  'type="button">\n'
#  '           <div class="wrap_footer_mb_menu main_font font-18" '
#  'data-value="2">\n'
#  '            เที่ยวไทย\n'
#  '            <div class="footer_mb_arrow" data-value="2">\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </button>\n'
#  '          <div class="collapse">\n'
#  '           <div class="wrap_footer_mb_all_sub_menu">\n'
#  '            <div class="wrap_footer_mb_sub_menu">\n'
#  '             <a href="/explore/promotion">\n'
#  '              <div class="footer_circle">\n'
#  '              </div>\n'
#  '              โปรโมชั่น\n'
#  '             </a>\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </div>\n'
#  '         </div>\n'
#  '         <div class="wrap_footer_mb_menu_item" data-value="3" id="item_3">\n'
#  '          <button class="btn btn-link" data-item="3" data-value="3" '
#  'type="button">\n'
#  '           <div class="wrap_footer_mb_menu main_font font-18" '
#  'data-value="3">\n'
#  '            คู่มือสนามบิน\n'
#  '            <div class="footer_mb_arrow" data-value="3">\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </button>\n'
#  '          <div class="collapse">\n'
#  '           <div class="wrap_footer_mb_all_sub_menu">\n'
#  '            <div class="wrap_footer_mb_sub_menu">\n'
#  '             <a href="/service/airport-guide">\n'
#  '              <div class="footer_circle">\n'
#  '              </div>\n'
#  '              คำแนะนำผู้โดยสาร\n'
#  '             </a>\n'
#  '            </div>\n'
#  '            <div class="wrap_footer_mb_sub_menu">\n'
#  '             <a href="/service/facility">\n'
#  '              <div class="footer_circle">\n'
#  '              </div>\n'
#  '              บริการภายในสนามบิน\n'
#  '             </a>\n'
#  '            </div>\n'
#  '            <div class="wrap_footer_mb_sub_menu">\n'
#  '             <a href="/service/shop-and-dine">\n'
#  '              <div class="footer_circle">\n'
#  '              </div>\n'
#  '              ร้านค้าและร้านอาหาร\n'
#  '             </a>\n'
#  '            </div>\n'
#  '            <div class="wrap_footer_mb_sub_menu">\n'
#  '             <a href="/service/transportation">\n'
#  '              <div class="footer_circle">\n'
#  '              </div>\n'
#  '              การเดินทาง\n'
#  '             </a>\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </div>\n'
#  '         </div>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '       <div class="w-100 mb_hidden">\n'
#  '        <div class="footer_main_menu row">\n'
#  '         <div class="col-md-6 col-12">\n'
#  '          <div class="main_font">\n'
#  '           เที่ยวบิน\n'
#  '          </div>\n'
#  '          <ul>\n'
#  '           <li>\n'
#  '            <a href="/flight?type=a">\n'
#  '             เที่ยวบินเข้า\n'
#  '            </a>\n'
#  '           </li>\n'
#  '           <li>\n'
#  '            <a href="/flight?type=d">\n'
#  '             เที่ยวบินออก\n'
#  '            </a>\n'
#  '           </li>\n'
#  '          </ul>\n'
#  '         </div>\n'
#  '         <div class="col-md-6 col-12">\n'
#  '          <div class="main_font">\n'
#  '           สิทธิพิเศษ\n'
#  '          </div>\n'
#  '          <ul>\n'
#  '           <li>\n'
#  '            <a href="/promotion/privilege">\n'
#  '             สิทธิพิเศษ\n'
#  '            </a>\n'
#  '           </li>\n'
#  '           <li>\n'
#  '            <a href="/promotion/booking">\n'
#  '             จองสิทธิพิเศษ\n'
#  '            </a>\n'
#  '           </li>\n'
#  '          </ul>\n'
#  '         </div>\n'
#  '         <div class="col-md-6 col-12">\n'
#  '          <div class="main_font">\n'
#  '           เที่ยวไทย\n'
#  '          </div>\n'
#  '          <ul>\n'
#  '           <li>\n'
#  '            <a href="/explore/promotion">\n'
#  '             โปรโมชั่น\n'
#  '            </a>\n'
#  '           </li>\n'
#  '          </ul>\n'
#  '         </div>\n'
#  '         <div class="col-md-6 col-12">\n'
#  '          <div class="main_font">\n'
#  '           คู่มือสนามบิน\n'
#  '          </div>\n'
#  '          <ul>\n'
#  '           <li>\n'
#  '            <a href="/service/airport-guide">\n'
#  '             คำแนะนำผู้โดยสาร\n'
#  '            </a>\n'
#  '           </li>\n'
#  '           <li>\n'
#  '            <a href="/service/facility">\n'
#  '             บริการภายในสนามบิน\n'
#  '            </a>\n'
#  '           </li>\n'
#  '           <li>\n'
#  '            <a href="/service/shop-and-dine">\n'
#  '             ร้านค้าและร้านอาหาร\n'
#  '            </a>\n'
#  '           </li>\n'
#  '           <li>\n'
#  '            <a href="/service/transportation">\n'
#  '             การเดินทาง\n'
#  '            </a>\n'
#  '           </li>\n'
#  '          </ul>\n'
#  '         </div>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '      </div>\n'
#  '      <div class="col-md-6 col-12" style="padding-top:20px">\n'
#  '       <div class="row">\n'
#  '        <div class="col-md-5 col-12">\n'
#  '         <div class="row">\n'
#  '          <div class="mt-2 col-md-12 col-8">\n'
#  '           <img alt="call_icon" class="d-inline-block align-top icon_size" '
#  'src="/images/footer/Icon-05.svg"/>\n'
#  '           <a href="tel:0221321888">\n'
#  '            Call Center (66)2132 - 1888\n'
#  '           </a>\n'
#  '          </div>\n'
#  '         </div>\n'
#  '        </div>\n'
#  '        <div class="mb_mt_20 col-md-7 col-12">\n'
#  '         <span>\n'
#  '          สมัครเพื่อติดตามข่าวสาร\n'
#  '         </span>\n'
#  '         <div class="wrap_signup_news">\n'
#  '          <form class="parent" id="form_newsletter">\n'
#  '           <input class="input_signup_news" name="email" '
#  'placeholder="ที่อยู่อีเมลของคุณ" required="" type="email"/>\n'
#  '           <button class="btn_signup_news btn btn-primary" type="submit">\n'
#  '            บันทึก\n'
#  '            <!-- -->\n'
#  '           </button>\n'
#  '          </form>\n'
#  '         </div>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '       <div class="space_social_link row">\n'
#  '        <div class="mb-3 mb_mt_20 col-md-5 col-12 order-md-1 order-3">\n'
#  '         <table class="social_link">\n'
#  '          <tbody>\n'
#  '           <tr>\n'
#  '            <td>\n'
#  '             <a href="https://www.facebook.com/AOTofficial" '
#  'target="_blank">\n'
#  '              <img alt="social_icon" class="d-inline-block align-top '
#  'icon_size" src="/images/footer/Icon-01.svg"/>\n'
#  '             </a>\n'
#  '            </td>\n'
#  '            <td>\n'
#  '             <a href="https://line.me/R/ti/p/@889xttyg?from=page" '
#  'target="_blank">\n'
#  '              <img alt="social_icon" class="d-inline-block align-top '
#  'icon_size" src="/images/footer/Icon-02.svg"/>\n'
#  '             </a>\n'
#  '            </td>\n'
#  '            <td>\n'
#  '             <a href="https://www.instagram.com/aot_official_th" '
#  'target="_blank">\n'
#  '              <img alt="social_icon" class="d-inline-block align-top '
#  'icon_size" src="/images/footer/Icon-03.svg"/>\n'
#  '             </a>\n'
#  '            </td>\n'
#  '            <td>\n'
#  '             <a href="https://twitter.com/AOTthailand" target="_blank">\n'
#  '              <img alt="social_icon" class="d-inline-block align-top '
#  'icon_size" src="/images/footer/Icon-04.svg"/>\n'
#  '             </a>\n'
#  '            </td>\n'
#  '           </tr>\n'
#  '          </tbody>\n'
#  '         </table>\n'
#  '        </div>\n'
#  '        <div class="desktop_hide col-12 order-md-2 order-2">\n'
#  '         <hr/>\n'
#  '        </div>\n'
#  '        <div class="col-md-7 col-12 order-md-3 order-1">\n'
#  '         <table class="app_link">\n'
#  '          <tbody>\n'
#  '           <tr>\n'
#  '            <td>\n'
#  '             <img alt="app_icon" class="d-inline-block align-top '
#  'aot_app_icon" src="/images/footer/Icon-app.png"/>\n'
#  '            </td>\n'
#  '            <td>\n'
#  '             <div>\n'
#  '              Free Download\n'
#  '             </div>\n'
#  '             <a '
#  'href="https://apps.apple.com/th/app/aot-airports/id792579639" '
#  'target="_blank">\n'
#  '              <img alt="social_icon" class="d-inline-block align-top '
#  'img_store" src="/images/footer/app_store.png"/>\n'
#  '             </a>\n'
#  '             <a href="https://play.google.com/store/apps/details?id=com.AOT" '
#  'target="_blank">\n'
#  '              <img alt="social_icon" class="d-inline-block align-top '
#  'img_store" src="/images/footer/play_store.png"/>\n'
#  '             </a>\n'
#  '            </td>\n'
#  '           </tr>\n'
#  '          </tbody>\n'
#  '         </table>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '     <div class="footer_right row">\n'
#  '      <div class="mb_hide col-12">\n'
#  '       <hr/>\n'
#  '      </div>\n'
#  '      <div class="mb_mt_20 col-md-6 col-12 order-md-1 order-2">\n'
#  '       <span class="text_right">\n'
#  '        ©2021 Airport of Thailand Public Co.,Ltd All rights reserved.\n'
#  '       </span>\n'
#  '      </div>\n'
#  '      <div class="mb_mt_20 col-md-6 col-12 order-md-2 order-1">\n'
#  '       <div class="site_link">\n'
#  '        <div class="d-inline-block">\n'
#  '         <a href="/term-and-condition">\n'
#  '          เงื่อนไขและข้อกำหนด\n'
#  '         </a>\n'
#  '        </div>\n'
#  '        <div class="d-inline-block">\n'
#  '         <a href="/privacy-policy">\n'
#  '          นโยบายความเป็นส่วนตัว\n'
#  '         </a>\n'
#  '        </div>\n'
#  '        <div class="d-inline-block">\n'
#  '         <a href="/about-us">\n'
#  '          เกี่ยวกับเรา\n'
#  '         </a>\n'
#  '        </div>\n'
#  '        <div class="d-inline-block">\n'
#  '         <a href="/faq">\n'
#  '          คำถามที่พบบ่อย\n'
#  '         </a>\n'
#  '        </div>\n'
#  '        <div class="d-inline-block">\n'
#  '         <a href="/cookie-policy">\n'
#  '          นโยบายคุกกี้\n'
#  '         </a>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </div>\n'
#  '   </footer>\n'
#  '   <div class="wrap_cookie_accept hide" id="wrap_cookie_accept">\n'
#  '    <div class="padding">\n'
#  '     <div class="font-17">\n'
#  '      เว็บไซต์นี้มีการใช้งานคุกกี้\n'
#  '     </div>\n'
#  '    </div>\n'
#  '    <div class="hr">\n'
#  '    </div>\n'
#  '    <div class="padding">\n'
#  '     <div class="font-14 font-xs-13 font-light">\n'
#  '      เราประมวลผลข้อมูลส่วนบุคคลของผู้ใช้บริการเว็บไซต์ AOT '
#  'ตามที่ระบุในนโยบายคุ้มครองข้อมูลมูลส่วนบุคคลนี้ซึ่งจะได้รับการดูแลตามมาตรฐานสูงสุดสอดคล้องกับพระราชบัญญัติคุ้มครองข้อมูลส่วนบุคคล '
#  'พ.ศ. 2562 โดยท่านสามารถดูรายละเอียดของนโยบายเพิ่มเติ่มใน\n'
#  '      <u class="main_font font-reg pointer">\n'
#  '       นโยบายคุกกี้\n'
#  '      </u>\n'
#  '     </div>\n'
#  '     <div class="wrap_button_group">\n'
#  '      <div class="btn_cookie_accept">\n'
#  '       ยอมรับ\n'
#  '      </div>\n'
#  '      <div class="btn_cookie_decline">\n'
#  '       ปฏิเสธ\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </div>\n'
#  '    <div class="btn_close">\n'
#  '     X\n'
#  '    </div>\n'
#  '   </div>\n'
#  '  </div>\n'
#  '  <script id="__NEXT_DATA__" type="application/json">\n'
#  '   '
#  '{"props":{"pageProps":{"dataAll":{"textMenu":[{"sysmenu_id":7,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"fight '
#  'status","smenulang_name":"เที่ยวบิน","smenulang_des":"ติดตามผู้โดยสารที่มาถึงเที่ยวบินพร้อมการอัปเดต","syslang_code":"th","sysmenu_url":"flight/","sysmenu_type":1,"sysmenu_level":1,"sysmenu_sort":1,"sysmenu_icon":"...","row_num":1}],"langs":[{"syslang_id":1,"syslang_code":"th","syslang_name":"ไทย"},{"syslang_id":2,"syslang_code":"en","syslang_name":"English"}],"sites":[{"sysmenu_id":1,"sysmenu_name":"suvarnabhumi","smenulang_name":"ท่าอากาศยานสุวรรณภูมิ","smenulang_des":"...","syslang_code":"th","sysmenu_url":"https://suvarnabhumi.airportthai.co.th/","sysmenu_sort":1,"site_code":"BKK","apisite_id":1,"row_num":1},{"sysmenu_id":2,"sysmenu_name":"donmueang","smenulang_name":"ท่าอากาศยานดอนเมือง","smenulang_des":"...","syslang_code":"th","sysmenu_url":"https://donmueang.airportthai.co.th/","sysmenu_sort":2,"site_code":"DMK","apisite_id":2,"row_num":1},{"sysmenu_id":3,"sysmenu_name":"chiangmai","smenulang_name":"ท่าอากาศยานเชียงใหม่","smenulang_des":"...","syslang_code":"th","sysmenu_url":"https://chiangmai.airportthai.co.th/","sysmenu_sort":3,"site_code":"CNX","apisite_id":3,"row_num":1},{"sysmenu_id":4,"sysmenu_name":"chiangrai","smenulang_name":"ท่าอากาศยานแม่ฟ้าหลวง '
#  'เชียงราย","smenulang_des":"...","syslang_code":"th","sysmenu_url":"https://chiangrai.airportthai.co.th/","sysmenu_sort":4,"site_code":"CEI","apisite_id":4,"row_num":1},{"sysmenu_id":5,"sysmenu_name":"hatyai","smenulang_name":"ท่าอากาศยานหาดใหญ่","smenulang_des":"...","syslang_code":"th","sysmenu_url":"https://hatyai.airportthai.co.th/","sysmenu_sort":5,"site_code":"HDY","apisite_id":6,"row_num":1},{"sysmenu_id":6,"sysmenu_name":"phuket","smenulang_name":"ท่าอากาศยานภูเก็ต","smenulang_des":"...","syslang_code":"th","sysmenu_url":"https://phuket.airportthai.co.th/","sysmenu_sort":6,"site_code":"HKT","apisite_id":7,"row_num":1}],"navbars":[{"sysmenu_id":7,"sysmenu_name":"fight '
#  'status","smenulang_name":"เที่ยวบิน","syslang_code":"th","sysmenu_url":"flight/","sysmenu_sort":1,"row_num":1},{"sysmenu_id":8,"sysmenu_name":"airport '
#  'guide","smenulang_name":"คู่มือสนามบิน","syslang_code":"th","sysmenu_url":"service/","sysmenu_sort":2,"row_num":1},{"sysmenu_id":9,"sysmenu_name":"promotion '
#  '\\u0026 '
#  'service","smenulang_name":"สิทธิพิเศษ","syslang_code":"th","sysmenu_url":"promotion/","sysmenu_sort":3,"row_num":1},{"sysmenu_id":10,"sysmenu_name":"expolre","smenulang_name":"เที่ยวไทย","syslang_code":"th","sysmenu_url":"explore/","sysmenu_sort":4,"row_num":1},{"sysmenu_id":11,"sysmenu_name":"contact '
#  'us","smenulang_name":"ติดต่อเรา","syslang_code":"th","sysmenu_url":"contact-us/","sysmenu_sort":5,"row_num":1}],"footers":[{"sysmenu_id":12,"sysmenu_sysmenu_id_fk":7,"sysmenu_name":"Flight '
#  'Arrival","smenulang_name":"เที่ยวบินเข้า","syslang_code":"th","sysmenu_url":"flight?type=a","sysmenu_sort":0,"row_num":1},{"sysmenu_id":13,"sysmenu_sysmenu_id_fk":7,"sysmenu_name":"Flight '
#  'Departure","smenulang_name":"เที่ยวบินออก","syslang_code":"th","sysmenu_url":"flight?type=d","sysmenu_sort":0,"row_num":1},{"sysmenu_id":14,"sysmenu_sysmenu_id_fk":9,"sysmenu_name":"Promotion '
#  '\\u0026 '
#  'Privilege","smenulang_name":"สิทธิพิเศษ","syslang_code":"th","sysmenu_url":"promotion/privilege/","sysmenu_sort":0,"row_num":1},{"sysmenu_id":15,"sysmenu_sysmenu_id_fk":9,"sysmenu_name":"Privilege '
#  'Booking","smenulang_name":"จองสิทธิพิเศษ","syslang_code":"th","sysmenu_url":"promotion/booking/","sysmenu_sort":0,"row_num":1},{"sysmenu_id":7,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"fight '
#  'status","smenulang_name":"เที่ยวบิน","syslang_code":"th","sysmenu_url":"flight/","sysmenu_sort":1,"row_num":1},{"sysmenu_id":23,"sysmenu_sysmenu_id_fk":8,"sysmenu_name":"Passenger '
#  'Guides","smenulang_name":"คำแนะนำผู้โดยสาร","syslang_code":"th","sysmenu_url":"service/airport-guide/","sysmenu_sort":1,"row_num":1},{"sysmenu_id":24,"sysmenu_sysmenu_id_fk":8,"sysmenu_name":"Facilities '
#  '\\u0026 '
#  'Service","smenulang_name":"บริการภายในสนามบิน","syslang_code":"th","sysmenu_url":"service/facility/","sysmenu_sort":2,"row_num":1},{"sysmenu_id":9,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"promotion '
#  '\\u0026 '
#  'service","smenulang_name":"สิทธิพิเศษ","syslang_code":"th","sysmenu_url":"promotion/","sysmenu_sort":2,"row_num":1},{"sysmenu_id":26,"sysmenu_sysmenu_id_fk":8,"sysmenu_name":"Shop '
#  '\\u0026 '
#  'Dine","smenulang_name":"ร้านค้าและร้านอาหาร","syslang_code":"th","sysmenu_url":"service/shop-and-dine/","sysmenu_sort":3,"row_num":1},{"sysmenu_id":10,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"expolre","smenulang_name":"เที่ยวไทย","syslang_code":"th","sysmenu_url":"explore/","sysmenu_sort":3,"row_num":1},{"sysmenu_id":25,"sysmenu_sysmenu_id_fk":8,"sysmenu_name":"Transportation","smenulang_name":"การเดินทาง","syslang_code":"th","sysmenu_url":"service/transportation/","sysmenu_sort":4,"row_num":1},{"sysmenu_id":8,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"airport '
#  'guide","smenulang_name":"คู่มือสนามบิน","syslang_code":"th","sysmenu_url":"service/","sysmenu_sort":4,"row_num":1},{"sysmenu_id":29,"sysmenu_sysmenu_id_fk":10,"sysmenu_name":"Promotion","smenulang_name":"โปรโมชั่น","syslang_code":"th","sysmenu_url":"explore/promotion/","sysmenu_sort":7,"row_num":1}],"bottoms":[{"sysmenu_id":30,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"Term '
#  '\\u0026 '
#  'Condition","smenulang_name":"เงื่อนไขและข้อกำหนด","syslang_code":"th","sysmenu_url":"term-and-condition","sysmenu_type":1,"sysmenu_level":1,"sysmenu_sort":1,"sysmenu_icon":"...","row_num":1},{"sysmenu_id":31,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"Privacy '
#  'Policy","smenulang_name":"นโยบายความเป็นส่วนตัว","syslang_code":"th","sysmenu_url":"privacy-policy","sysmenu_type":1,"sysmenu_level":1,"sysmenu_sort":2,"sysmenu_icon":"...","row_num":1},{"sysmenu_id":32,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"About '
#  'Us","smenulang_name":"เกี่ยวกับเรา","syslang_code":"th","sysmenu_url":"about-us","sysmenu_type":1,"sysmenu_level":1,"sysmenu_sort":3,"sysmenu_icon":"...","row_num":1},{"sysmenu_id":34,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"FAQ","smenulang_name":"คำถามที่พบบ่อย","syslang_code":"th","sysmenu_url":"faq","sysmenu_type":1,"sysmenu_level":1,"sysmenu_sort":5,"sysmenu_icon":"...","row_num":1},{"sysmenu_id":45,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"Cookie '
#  'Policy","smenulang_name":"นโยบายคุกกี้","syslang_code":"th","sysmenu_url":"cookie-policy","sysmenu_type":1,"sysmenu_level":1,"sysmenu_sort":6,"sysmenu_icon":"...","row_num":1}],"lang":[{"syslang_id":1,"syslang_code":"th","syslang_name":"ไทย"}],"site":[{"apisite_id":1,"site_code":"BKK","site_name":"suvarnabhumi","site_des":"...","sitelang_name":"ท่าอากาศยานสุวรรณภูมิ","sitelang_des":"...","row_num":1}],"menuLogin":[{"sysmenu_id":37,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"Login","smenulang_name":"เข้าสู่ระบบ","syslang_code":"th","sysmenu_url":"login","sysmenu_type":1,"sysmenu_level":2,"sysmenu_sort":0,"sysmenu_icon":"...","row_num":1}],"banners":[{"pc_id":51,"pc_origin_name":"เที่ยวบิน","pc_current_name":"IMG_3943.jpg","pc_path":"images/banners","mobile_id":52,"mobile_origin_name":"เที่ยวบิน","mobile_current_name":"IMG_3947.jpg","mobile_path":"images/banners","type":"banner","link":"#"}],"navigator":[{"type":"home","sysmenu_id":36,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"Home","smenulang_name":"หน้าแรก","smenulang_des":"...","syslang_code":"th","sysmenu_url":"","sysmenu_type":1,"sysmenu_level":2,"sysmenu_sort":0,"sysmenu_icon":"...","row_num":1,"sort":1},{"type":"current","sysmenu_id":7,"sysmenu_sysmenu_id_fk":0,"sysmenu_name":"fight '
#  'status","smenulang_name":"เที่ยวบิน","smenulang_des":"ติดตามผู้โดยสารที่มาถึงเที่ยวบินพร้อมการอัปเดต","syslang_code":"th","sysmenu_url":"flight/","sysmenu_type":1,"sysmenu_level":1,"sysmenu_sort":1,"sysmenu_icon":"...","row_num":1,"sort":2}],"extraText":[{"extra_id":12,"extra_name":"read '
#  'more","extralang_name":"อ่านเพิ่มเติม","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":13,"extra_name":"see '
#  'all","extralang_name":"ดูทั้งหมด","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":24,"extra_name":"refresh","extralang_name":"รีเฟรซ","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":25,"extra_name":"Text '
#  'Sign up for our '
#  'newsletter","extralang_name":"สมัครเพื่อติดตามข่าวสาร","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":26,"extra_name":"Placehoder '
#  'newsletter","extralang_name":"ที่อยู่อีเมลของคุณ","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":27,"extra_name":"Button '
#  'sing '
#  'up","extralang_name":"บันทึก","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":47,"extra_name":"ModalTitleNotify","extralang_name":"แจ้งเตือน","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":48,"extra_name":"ModalBodySuccess","extralang_name":"ส่งข้อมูลเรียบร้อย","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":49,"extra_name":"ModalButtonClose","extralang_name":"ปิด","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":51,"extra_name":"พิมพ์คำค้นหา","extralang_name":"พิมพ์คำค้นหา","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":52,"extra_name":"ค้นหา","extralang_name":"ค้นหา","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":53,"extra_name":"ดูเพิ่มเติม","extralang_name":"ดูเพิ่มเติม","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":60,"extra_name":"เลือกรายการ","extralang_name":"เลือกรายการ","extralang_des":"...","syslang_code":"th","row_num":1},{"extra_id":124,"extra_name":"สนามบิน","extralang_name":"สนามบิน","extralang_des":null,"syslang_code":"th","row_num":1}],"ads":[{"ads_id":19,"ads_start_dt":"2021-06-30T17:00:00.000Z","ads_end_dt":"2021-09-29T17:00:00.000Z","ads_origin_name":"...","ads_current_name":"MTI3.jpg","ads_path":"images/advertising","adsblock_position":"FlightStatus#Leaderboard","mobile_id":null,"mobile_origin_name":null,"mobile_current_name":null,"mobile_path":null,"type":"ads","link":"https://bit.ly/2U8GiIh"}]},"dataFlight":{"searchFlight":[{"extra_id":2,"extra_name":"Text '
#  'Arrivals","extra_data":"เที่ยวบินเข้า","syslang_code":"th","row_num":1},{"extra_id":1,"extra_name":"Text '
#  'Departures","extra_data":"เที่ยวบินออก","syslang_code":"th","row_num":1},{"extra_id":5,"extra_name":"Icon '
#  'Search","extra_data":"images/icons/AOT-11.png","syslang_code":"all","row_num":1},{"extra_id":23,"extra_name":"thailand-time","extra_data":"เวลาประเทศไทย '
#  'GMT+7","syslang_code":"th","row_num":1},{"extra_id":22,"extra_name":"last-update","extra_data":"ข้อมูลล่าสุด","syslang_code":"th","row_num":1},{"extra_id":11,"extra_name":"Placeholder:A","extra_data":"ค้นหาเที่ยวบินเข้า","syslang_code":"th","row_num":1},{"extra_id":4,"extra_name":"Text '
#  'Search","extra_data":"ค้นหา","syslang_code":"th","row_num":1},{"extra_id":3,"extra_name":"Placeholder:D","extra_data":"ค้นหาเที่ยวบินออก","syslang_code":"th","row_num":1}]}},"__N_SSP":true},"page":"/flight","query":{},"buildId":"o6T8lMRcUjXDWK9ppk7N5","isFallback":false,"gssp":true}\n'
#  '  </script>\n'
#  '  <script nomodule="" '
#  'src="/_next/static/chunks/polyfills-6e054d56079d4b93ebe8.js">\n'
#  '  </script>\n'
#  '  <script async="" '
#  'src="/_next/static/chunks/webpack-fe4b4968ddeab099efef.js">\n'
#  '  </script>\n'
#  '  <script async="" '
#  'src="/_next/static/chunks/framework-106d25c2ed81dc45938c.js">\n'
#  '  </script>\n'
#  '  <script async="" src="/_next/static/chunks/main-1edd7ef5819b2a11bbed.js">\n'
#  '  </script>\n'
#  '  <script async="" '
#  'src="/_next/static/chunks/pages/_app-d75b3491177b58aeb9b6.js">\n'
#  '  </script>\n'
#  '  <script async="" '
#  'src="/_next/static/chunks/29107295-a36037e5ea1af0472eba.js">\n'
#  '  </script>\n'
#  '  <script async="" '
#  'src="/_next/static/chunks/cb1608f2-0acd0fa0d973384ecfed.js">\n'
#  '  </script>\n'
#  '  <script async="" '
#  'src="/_next/static/chunks/75fc9c18-5f9e88d02b7fe80f33f9.js">\n'
#  '  </script>\n'
#  '  <script async="" src="/_next/static/chunks/6067-d5bbd6667205f733b73a.js">\n'
#  '  </script>\n'
#  '  <script async="" src="/_next/static/chunks/4635-893cbd8a482370a1a834.js">\n'
#  '  </script>\n'
#  '  <script async="" src="/_next/static/chunks/2959-4bb853920bbbf98e78e0.js">\n'
#  '  </script>\n'
#  '  <script async="" src="/_next/static/chunks/1796-bd3f82c7fdb482ac6e18.js">\n'
#  '  </script>\n'
#  '  <script async="" src="/_next/static/chunks/2238-f7ba2e2bd779585fd5b7.js">\n'
#  '  </script>\n'
#  '  <script async="" src="/_next/static/chunks/9607-1201740d0f1621f67209.js">\n'
#  '  </script>\n'
#  '  <script async="" '
#  'src="/_next/static/chunks/pages/flight-8506b04b6caec7ae1fa9.js">\n'
#  '  </script>\n'
#  '  <script async="" '
#  'src="/_next/static/o6T8lMRcUjXDWK9ppk7N5/_buildManifest.js">\n'
#  '  </script>\n'
#  '  <script async="" '
#  'src="/_next/static/o6T8lMRcUjXDWK9ppk7N5/_ssgManifest.js">\n'
#  '  </script>\n'
#  ' </body>\n'
#  '</html>')

# %%
all_inputs = []
for _ in soup.find_all("div", {"class": "wrap_input_group parent"}):
    all_inputs.append(_)

print(all_inputs)
# Out:
# [<div class="wrap_input_group parent"><input/><img alt="" class="absolute" src="../../../images/main/i_calendar.svg"/></div>]
